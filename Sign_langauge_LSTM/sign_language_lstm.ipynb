# %%
pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\abhishek\anaconda3\lib\site-packages (0.10.2)
# Requirement already satisfied: opencv-python in c:\users\abhishek\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: absl-py in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: numpy in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (1.21.5)
# Requirement already satisfied: opencv-contrib-python in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (4.8.0.74)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\abhishek\anaconda3\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\users\abhishek\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhishek\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhishek\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abhishek\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhishek\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abhishek\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abhishek\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhishek\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\abhishek\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\abhishek\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import mediapipe as mp
import os
import time

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/1b/66/2f47c39cfedb29188d82555d0184a619a0bf8234fd5e5301940efb0aa464/tensorflow-2.13.0-cp39-cp39-win_amd64.whl.metadata
#   Downloading tensorflow-2.13.0-cp39-cp39-win_amd64.whl.metadata (2.6 kB)
# Collecting tensorflow-intel==2.13.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-intel==2.13.0 from https://files.pythonhosted.org/packages/2b/ad/d3a2e335004d178e0599cf8aff6c2a92cd21eb9789358fb8f3f951009930/tensorflow_intel-2.13.0-cp39-cp39-win_amd64.whl.metadata
#   Downloading tensorflow_intel-2.13.0-cp39-cp39-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/02/8c/dc970bc00867fe290e8c8a7befa1635af716a9ebdfe3fb9dce0ca4b522ce/libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata
#   Downloading libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting numpy<=1.24.3,>=1.22 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading numpy-1.24.3-cp39-cp39-win_amd64.whl (14.9 MB)
#      --------------------------------------- 14.9/14.9 MB 10.2 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB ? eta 0:00:00
# Requirement already satisfied: packaging in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (63.4.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for grpcio<2.0,>=1.24.3 from https://files.pythonhosted.org/packages/ae/db/95f02013559bb354ac51dc0f4f302f71d42d0e03ac86b50001233ed07533/grpcio-1.56.2-cp39-cp39-win_amd64.whl.metadata
#   Downloading grpcio-1.56.2-cp39-cp39-win_amd64.whl.metadata (4.1 kB)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 7.4 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.14,>=2.13.0 from https://files.pythonhosted.org/packages/72/5c/c318268d96791c6222ad7df1651bbd1b2409139afeb6f468c0f327177016/tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for keras<2.14,>=2.13.1 from https://files.pythonhosted.org/packages/2e/f3/19da7511b45e80216cbbd9467137b2d28919c58ba1ccb971435cb631e470/keras-2.13.1-py3-none-any.whl.metadata
#   Downloading keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\abhishek\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.37.1)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/9c/8d/bff87fc722553a5691d8514da5523c23547f3894189ba03b57592e37bdc2/google_auth-2.22.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.28.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\abhishek\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abhishek\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow) (3.0.9)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhishek\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3<2.0 in c:\users\abhishek\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.11)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\abhishek\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhishek\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhishek\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\abhishek\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abhishek\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Downloading tensorflow-2.13.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Downloading tensorflow_intel-2.13.0-cp39-cp39-win_amd64.whl (276.5 MB)
#    ---------------------------------------- 276.5/276.5 MB 5.5 MB/s eta 0:00:00
# Downloading grpcio-1.56.2-cp39-cp39-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 4.2/4.2 MB 11.3 MB/s eta 0:00:00
# Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 1.7/1.7 MB 10.8 MB/s eta 0:00:00
# Downloading libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 24.4/24.4 MB 10.7 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#    ---------------------------------------- 440.8/440.8 kB 9.2 MB/s eta 0:00:00
# Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#    --------------------------------------- 181.8/181.8 kB 10.7 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Installing collected packages: libclang, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, numpy, keras, grpcio, google-pasta, gast, cachetools, astunparse, requests-oauthlib, opt-einsum, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed astunparse-1.6.3 cachetools-5.3.1 gast-0.4.0 google-auth-2.22.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.56.2 keras-2.13.1 libclang-16.0.6 numpy-1.24.3 opt-einsum-3.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-intel-2.13.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.3 which is incompatible.

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR CONVERSION RGB 2 BGR
    return image, results

def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)

def rescale_frame(frame, percent=75):
    width = int(frame.shape[1] * percent/ 100)
    height = int(frame.shape[0] * percent/ 100)
    dim = (width, height)
    return cv2.resize(frame, dim, interpolation =cv2.INTER_AREA)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
        frame150 = rescale_frame(frame, percent=150)
        # Make detections
        image, results = mediapipe_detection(frame150, holistic)
        # print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
len(results.face_landmarks.landmark)
# Out:
# 468

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.42073917,  0.58904862, -0.69655037, ...,  0.        ,
#         0.        ,  0.        ])

# %%
os.path
# Out:
# <module 'ntpath' from 'c:\\Users\\Abhishek\\anaconda3\\lib\\ntpath.py'>

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join(os.getcwd(),'Sign_Data') 

# Actions that we try to detect
actions = np.array(['hello','yes', 'no', 'thanks'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions: 
    # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()
                frame150 = rescale_frame(frame, percent=150)
                # Make detections
                image, results = mediapipe_detection(frame150, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'yes': 1, 'no': 2, 'thanks': 3}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
X.shape
# Out:
# (120, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (6, 4)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join(os.getcwd(),'Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 3s 73ms/step - loss: 6.6679 - categorical_accuracy: 0.2982
# Epoch 2/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 9.6249 - categorical_accuracy: 0.1930
# Epoch 3/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 74.6051 - categorical_accuracy: 0.3070
# Epoch 4/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 22.1217 - categorical_accuracy: 0.2368
# Epoch 5/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 6.8618 - categorical_accuracy: 0.2105
# Epoch 6/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 12.8522 - categorical_accuracy: 0.2807
# Epoch 7/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 14.5497 - categorical_accuracy: 0.2544
# Epoch 8/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 30.9067 - categorical_accuracy: 0.2719
# Epoch 9/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 47.9537 - categorical_accuracy: 0.2544
# Epoch 10/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 46.1568 - categorical_accuracy: 0.2632
# Epoch 11/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 29.8836 - categorical_accuracy: 0.1930
# Epoch 12/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 15.4194 - categorical_accuracy: 0.2719
# Epoch 13/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 63.1674 - categorical_accuracy: 0.2281
# Epoch 14/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 52.7017 - categorical_accuracy: 0.2281
# Epoch 15/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 68.7775 - categorical_accuracy: 0.2544
# Epoch 16/2000
# 4/4 [==============================] - 0s 78ms/step - loss: 235.8582 - categorical_accuracy: 0.2281
# Epoch 17/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 310.5875 - categorical_accuracy: 0.2719
# Epoch 18/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 237.5155 - categorical_accuracy: 0.2368
# Epoch 19/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 350.4606 - categorical_accuracy: 0.2632
# Epoch 20/2000
# 4/4 [==============================] - 0s 82ms/step - loss: 180.8244 - categorical_accuracy: 0.2807
# Epoch 21/2000
# 4/4 [==============================] - 0s 81ms/step - loss: 135.7947 - categorical_accuracy: 0.2807
# Epoch 22/2000
# 4/4 [==============================] - 0s 79ms/step - loss: 53.7875 - categorical_accuracy: 0.2982
# Epoch 23/2000
# 4/4 [==============================] - 0s 81ms/step - loss: 36.7251 - categorical_accuracy: 0.2105
# Epoch 24/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 37.3003 - categorical_accuracy: 0.2544
# Epoch 25/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 32.2339 - categorical_accuracy: 0.3333
# Epoch 26/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 20.4438 - categorical_accuracy: 0.2281
# Epoch 27/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 29.4320 - categorical_accuracy: 0.2368
# Epoch 28/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 24.6153 - categorical_accuracy: 0.1842
# Epoch 29/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 29.5641 - categorical_accuracy: 0.3246
# Epoch 30/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 29.3485 - categorical_accuracy: 0.2193
# Epoch 31/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 41.8372 - categorical_accuracy: 0.2807
# Epoch 32/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 51.9993 - categorical_accuracy: 0.2368
# Epoch 33/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 41.4883 - categorical_accuracy: 0.2807
# Epoch 34/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 34.0712 - categorical_accuracy: 0.3509
# Epoch 35/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 31.9648 - categorical_accuracy: 0.3246
# Epoch 36/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 38.3308 - categorical_accuracy: 0.2456
# Epoch 37/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 47.6764 - categorical_accuracy: 0.2281
# Epoch 38/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 70.8019 - categorical_accuracy: 0.2193
# Epoch 39/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 42.9331 - categorical_accuracy: 0.1667
# Epoch 40/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 26.6614 - categorical_accuracy: 0.2632
# Epoch 41/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 50.3547 - categorical_accuracy: 0.3158
# Epoch 42/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 36.4863 - categorical_accuracy: 0.2544
# Epoch 43/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 21.9843 - categorical_accuracy: 0.2193
# Epoch 44/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 24.2463 - categorical_accuracy: 0.2456
# Epoch 45/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 60.6228 - categorical_accuracy: 0.2456
# Epoch 46/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 91.3366 - categorical_accuracy: 0.2807
# Epoch 47/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 52.9227 - categorical_accuracy: 0.2719
# Epoch 48/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 87.4312 - categorical_accuracy: 0.2544
# Epoch 49/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 103.0770 - categorical_accuracy: 0.2982
# Epoch 50/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 110.8383 - categorical_accuracy: 0.3070
# Epoch 51/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 182.5150 - categorical_accuracy: 0.2193
# Epoch 52/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 242.9303 - categorical_accuracy: 0.2368
# Epoch 53/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 238.0240 - categorical_accuracy: 0.2982
# Epoch 54/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 194.8740 - categorical_accuracy: 0.2018
# Epoch 55/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 234.9859 - categorical_accuracy: 0.2544
# Epoch 56/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 168.3608 - categorical_accuracy: 0.2281
# Epoch 57/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 163.1954 - categorical_accuracy: 0.2281
# Epoch 58/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 170.9634 - categorical_accuracy: 0.3070
# Epoch 59/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 154.9978 - categorical_accuracy: 0.2544
# Epoch 60/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 171.8449 - categorical_accuracy: 0.1930
# Epoch 61/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 124.7438 - categorical_accuracy: 0.2193
# Epoch 62/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 90.0866 - categorical_accuracy: 0.2807
# Epoch 63/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 96.0366 - categorical_accuracy: 0.2281
# Epoch 64/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 148.9615 - categorical_accuracy: 0.2807
# Epoch 65/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 109.7007 - categorical_accuracy: 0.3070
# Epoch 66/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 207.8530 - categorical_accuracy: 0.3070
# Epoch 67/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 98.0543 - categorical_accuracy: 0.2982
# Epoch 68/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 161.5611 - categorical_accuracy: 0.2105
# Epoch 69/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 223.9809 - categorical_accuracy: 0.2719
# Epoch 70/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 159.8849 - categorical_accuracy: 0.3333
# Epoch 71/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 76.6321 - categorical_accuracy: 0.2982
# Epoch 72/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 107.6314 - categorical_accuracy: 0.2368
# Epoch 73/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 207.6343 - categorical_accuracy: 0.2193
# Epoch 74/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 236.0060 - categorical_accuracy: 0.1842
# Epoch 75/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 191.1476 - categorical_accuracy: 0.2281
# Epoch 76/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 264.9018 - categorical_accuracy: 0.2456
# Epoch 77/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 291.6392 - categorical_accuracy: 0.1842
# Epoch 78/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 257.0061 - categorical_accuracy: 0.2368
# Epoch 79/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 281.0697 - categorical_accuracy: 0.2105
# Epoch 80/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 218.8141 - categorical_accuracy: 0.2719
# Epoch 81/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 89.3488 - categorical_accuracy: 0.2719
# Epoch 82/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 153.0544 - categorical_accuracy: 0.2368
# Epoch 83/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 93.3520 - categorical_accuracy: 0.2544
# Epoch 84/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 126.6483 - categorical_accuracy: 0.2105
# Epoch 85/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 49.6455 - categorical_accuracy: 0.2544
# Epoch 86/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 67.7820 - categorical_accuracy: 0.2895
# Epoch 87/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 68.4228 - categorical_accuracy: 0.2895
# Epoch 88/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 51.4660 - categorical_accuracy: 0.2807
# Epoch 89/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 85.6898 - categorical_accuracy: 0.2018
# Epoch 90/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 90.2716 - categorical_accuracy: 0.2807
# Epoch 91/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 53.6411 - categorical_accuracy: 0.2719
# Epoch 92/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 63.4714 - categorical_accuracy: 0.2281
# Epoch 93/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 35.5113 - categorical_accuracy: 0.2105
# Epoch 94/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 59.1928 - categorical_accuracy: 0.3158
# Epoch 95/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 52.2528 - categorical_accuracy: 0.2105
# Epoch 96/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 68.7485 - categorical_accuracy: 0.1930
# Epoch 97/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 30.0771 - categorical_accuracy: 0.2632
# Epoch 98/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 37.7731 - categorical_accuracy: 0.2456
# Epoch 99/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 32.5861 - categorical_accuracy: 0.2105
# Epoch 100/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 41.1363 - categorical_accuracy: 0.2368
# Epoch 101/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 66.2925 - categorical_accuracy: 0.2193
# Epoch 102/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 62.4516 - categorical_accuracy: 0.2719
# Epoch 103/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 47.7532 - categorical_accuracy: 0.1930
# Epoch 104/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 47.0362 - categorical_accuracy: 0.2018
# Epoch 105/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 54.4914 - categorical_accuracy: 0.2281
# Epoch 106/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 26.8651 - categorical_accuracy: 0.2105
# Epoch 107/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 52.0618 - categorical_accuracy: 0.1930
# Epoch 108/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 41.3891 - categorical_accuracy: 0.2193
# Epoch 109/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 26.6160 - categorical_accuracy: 0.2544
# Epoch 110/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 25.2316 - categorical_accuracy: 0.2807
# Epoch 111/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 18.4493 - categorical_accuracy: 0.2807
# Epoch 112/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 34.3902 - categorical_accuracy: 0.2544
# Epoch 113/2000
# 4/4 [==============================] - 0s 62ms/step - loss: 21.2627 - categorical_accuracy: 0.2456
# Epoch 114/2000
# 4/4 [==============================] - 0s 62ms/step - loss: 28.4465 - categorical_accuracy: 0.2018
# Epoch 115/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 18.4993 - categorical_accuracy: 0.2456
# Epoch 116/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 29.7561 - categorical_accuracy: 0.2895
# Epoch 117/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 19.9213 - categorical_accuracy: 0.2456
# Epoch 118/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 26.1894 - categorical_accuracy: 0.2719
# Epoch 119/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 30.8294 - categorical_accuracy: 0.2895
# Epoch 120/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 18.5240 - categorical_accuracy: 0.2632
# Epoch 121/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 34.1302 - categorical_accuracy: 0.3070
# Epoch 122/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 17.9519 - categorical_accuracy: 0.2719
# Epoch 123/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 19.7049 - categorical_accuracy: 0.2193
# Epoch 124/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 15.9799 - categorical_accuracy: 0.2632
# Epoch 125/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 16.6304 - categorical_accuracy: 0.2368
# Epoch 126/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 19.8757 - categorical_accuracy: 0.2281
# Epoch 127/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 31.1376 - categorical_accuracy: 0.2632
# Epoch 128/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 22.4319 - categorical_accuracy: 0.2193
# Epoch 129/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 36.5641 - categorical_accuracy: 0.2105
# Epoch 130/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 32.2149 - categorical_accuracy: 0.2281
# Epoch 131/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 21.3699 - categorical_accuracy: 0.2105
# Epoch 132/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 14.9168 - categorical_accuracy: 0.1930
# Epoch 133/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 15.1089 - categorical_accuracy: 0.2807
# Epoch 134/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 19.0764 - categorical_accuracy: 0.2193
# Epoch 135/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 26.1826 - categorical_accuracy: 0.1930
# Epoch 136/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 21.9068 - categorical_accuracy: 0.1754
# Epoch 137/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 26.7141 - categorical_accuracy: 0.2368
# Epoch 138/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 23.3010 - categorical_accuracy: 0.2544
# Epoch 139/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 21.4696 - categorical_accuracy: 0.3421
# Epoch 140/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 35.5893 - categorical_accuracy: 0.2719
# Epoch 141/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 29.6812 - categorical_accuracy: 0.2719
# Epoch 142/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 44.2640 - categorical_accuracy: 0.2281
# Epoch 143/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 39.1000 - categorical_accuracy: 0.2632
# Epoch 144/2000
# 4/4 [==============================] - 0s 62ms/step - loss: 32.3350 - categorical_accuracy: 0.2281
# Epoch 145/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 25.3619 - categorical_accuracy: 0.2807
# Epoch 146/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 14.0562 - categorical_accuracy: 0.2368
# Epoch 147/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 10.9755 - categorical_accuracy: 0.2193
# Epoch 148/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 9.5590 - categorical_accuracy: 0.2368
# Epoch 149/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 8.3687 - categorical_accuracy: 0.2982
# Epoch 150/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 15.7518 - categorical_accuracy: 0.2632
# Epoch 151/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 9.9924 - categorical_accuracy: 0.2544
# Epoch 152/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 15.7508 - categorical_accuracy: 0.1930
# Epoch 153/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 17.7044 - categorical_accuracy: 0.2632
# Epoch 154/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 19.5952 - categorical_accuracy: 0.2368
# Epoch 155/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 18.7581 - categorical_accuracy: 0.2719
# Epoch 156/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 23.9342 - categorical_accuracy: 0.2456
# Epoch 157/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 14.5614 - categorical_accuracy: 0.2632
# Epoch 158/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 13.2621 - categorical_accuracy: 0.2018
# Epoch 159/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 9.6235 - categorical_accuracy: 0.2544
# Epoch 160/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 7.1755 - categorical_accuracy: 0.2281
# Epoch 161/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 9.5065 - categorical_accuracy: 0.1754
# Epoch 162/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 13.9295 - categorical_accuracy: 0.2193
# Epoch 163/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 18.5716 - categorical_accuracy: 0.2368
# Epoch 164/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 15.7724 - categorical_accuracy: 0.2456
# Epoch 165/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 17.5698 - categorical_accuracy: 0.2193
# Epoch 166/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 11.1819 - categorical_accuracy: 0.2193
# Epoch 167/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 14.2584 - categorical_accuracy: 0.2281
# Epoch 168/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 14.1772 - categorical_accuracy: 0.2456
# Epoch 169/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 16.5792 - categorical_accuracy: 0.2632
# Epoch 170/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 9.0838 - categorical_accuracy: 0.2719
# Epoch 171/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 10.8636 - categorical_accuracy: 0.2807
# Epoch 172/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 7.5660 - categorical_accuracy: 0.3246
# Epoch 173/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 17.5725 - categorical_accuracy: 0.2719
# Epoch 174/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 10.1513 - categorical_accuracy: 0.2544
# Epoch 175/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 17.3137 - categorical_accuracy: 0.2719
# Epoch 176/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 14.1905 - categorical_accuracy: 0.2456
# Epoch 177/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 48.6284 - categorical_accuracy: 0.2632
# Epoch 178/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 59.0564 - categorical_accuracy: 0.2982
# Epoch 179/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 175.8693 - categorical_accuracy: 0.2719
# Epoch 180/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 100.3003 - categorical_accuracy: 0.2544
# Epoch 181/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 79.6615 - categorical_accuracy: 0.2456
# Epoch 182/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 36.2116 - categorical_accuracy: 0.2632
# Epoch 183/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 39.2373 - categorical_accuracy: 0.2368
# Epoch 184/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 25.5117 - categorical_accuracy: 0.2281
# Epoch 185/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 26.0204 - categorical_accuracy: 0.3158
# Epoch 186/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 15.4210 - categorical_accuracy: 0.2456
# Epoch 187/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 14.2731 - categorical_accuracy: 0.2018
# Epoch 188/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 10.5019 - categorical_accuracy: 0.2544
# Epoch 189/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 8.0458 - categorical_accuracy: 0.3246
# Epoch 190/2000
# 4/4 [==============================] - 0s 75ms/step - loss: 9.3645 - categorical_accuracy: 0.2018
# Epoch 191/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 8.0492 - categorical_accuracy: 0.2456
# Epoch 192/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 10.9939 - categorical_accuracy: 0.2456
# Epoch 193/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 5.3683 - categorical_accuracy: 0.2105
# Epoch 194/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 7.7063 - categorical_accuracy: 0.2544
# Epoch 195/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 5.3077 - categorical_accuracy: 0.2018
# Epoch 196/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 4.3766 - categorical_accuracy: 0.2719
# Epoch 197/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 4.0897 - categorical_accuracy: 0.2544
# Epoch 198/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 3.5208 - categorical_accuracy: 0.1842
# Epoch 199/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.6748 - categorical_accuracy: 0.1754
# Epoch 200/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 2.6176 - categorical_accuracy: 0.2632
# Epoch 201/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 4.7248 - categorical_accuracy: 0.1491
# Epoch 202/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 5.7887 - categorical_accuracy: 0.2544
# Epoch 203/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 5.3042 - categorical_accuracy: 0.2719
# Epoch 204/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 5.7543 - categorical_accuracy: 0.2018
# Epoch 205/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 5.9876 - categorical_accuracy: 0.2018
# Epoch 206/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 9.1952 - categorical_accuracy: 0.2544
# Epoch 207/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 10.7740 - categorical_accuracy: 0.2544
# Epoch 208/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 7.1121 - categorical_accuracy: 0.2018
# Epoch 209/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 7.9861 - categorical_accuracy: 0.2807
# Epoch 210/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 3.9529 - categorical_accuracy: 0.3158
# Epoch 211/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 4.5020 - categorical_accuracy: 0.2719
# Epoch 212/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 6.9133 - categorical_accuracy: 0.2895
# Epoch 213/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 5.8925 - categorical_accuracy: 0.2982
# Epoch 214/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 5.3128 - categorical_accuracy: 0.2544
# Epoch 215/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 3.1477 - categorical_accuracy: 0.2719
# Epoch 216/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.9729 - categorical_accuracy: 0.2632
# Epoch 217/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.6074 - categorical_accuracy: 0.3158
# Epoch 218/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 3.2502 - categorical_accuracy: 0.2807
# Epoch 219/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.8115 - categorical_accuracy: 0.2368
# Epoch 220/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.3216 - categorical_accuracy: 0.2807
# Epoch 221/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 2.7651 - categorical_accuracy: 0.2281
# Epoch 222/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 3.7262 - categorical_accuracy: 0.2544
# Epoch 223/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 4.1129 - categorical_accuracy: 0.2982
# Epoch 224/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 3.5582 - categorical_accuracy: 0.2105
# Epoch 225/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.9221 - categorical_accuracy: 0.2193
# Epoch 226/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.7835 - categorical_accuracy: 0.2807
# Epoch 227/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 4.7396 - categorical_accuracy: 0.2018
# Epoch 228/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 4.0540 - categorical_accuracy: 0.2895
# Epoch 229/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.9271 - categorical_accuracy: 0.2281
# Epoch 230/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 3.1495 - categorical_accuracy: 0.2544
# Epoch 231/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 3.2473 - categorical_accuracy: 0.2807
# Epoch 232/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.4903 - categorical_accuracy: 0.2719
# Epoch 233/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.6848 - categorical_accuracy: 0.2632
# Epoch 234/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.2906 - categorical_accuracy: 0.2368
# Epoch 235/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.8072 - categorical_accuracy: 0.3333
# Epoch 236/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.7808 - categorical_accuracy: 0.3158
# Epoch 237/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.7362 - categorical_accuracy: 0.2456
# Epoch 238/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.8104 - categorical_accuracy: 0.2895
# Epoch 239/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.7338 - categorical_accuracy: 0.2544
# Epoch 240/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.9717 - categorical_accuracy: 0.2982
# Epoch 241/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.5440 - categorical_accuracy: 0.2982
# Epoch 242/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.2404 - categorical_accuracy: 0.2982
# Epoch 243/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.9829 - categorical_accuracy: 0.2544
# Epoch 244/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 2.0451 - categorical_accuracy: 0.2895
# Epoch 245/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.9692 - categorical_accuracy: 0.3246
# Epoch 246/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.6779 - categorical_accuracy: 0.3333
# Epoch 247/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.4239 - categorical_accuracy: 0.2368
# Epoch 248/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.2914 - categorical_accuracy: 0.2807
# Epoch 249/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.3654 - categorical_accuracy: 0.1930
# Epoch 250/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.8483 - categorical_accuracy: 0.2544
# Epoch 251/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 1.6880 - categorical_accuracy: 0.2456
# Epoch 252/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.7579 - categorical_accuracy: 0.3421
# Epoch 253/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.4480 - categorical_accuracy: 0.2632
# Epoch 254/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 2.8629 - categorical_accuracy: 0.2719
# Epoch 255/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.0092 - categorical_accuracy: 0.2719
# Epoch 256/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.2194 - categorical_accuracy: 0.2105
# Epoch 257/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.6450 - categorical_accuracy: 0.2982
# Epoch 258/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 2.5389 - categorical_accuracy: 0.3070
# Epoch 259/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 3.4780 - categorical_accuracy: 0.2193
# Epoch 260/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 4.5947 - categorical_accuracy: 0.3509
# Epoch 261/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 6.2402 - categorical_accuracy: 0.2105
# Epoch 262/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 5.1918 - categorical_accuracy: 0.2632
# Epoch 263/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 4.7676 - categorical_accuracy: 0.2719
# Epoch 264/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 6.4676 - categorical_accuracy: 0.2193
# Epoch 265/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 4.6445 - categorical_accuracy: 0.2544
# Epoch 266/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 5.5095 - categorical_accuracy: 0.1930
# Epoch 267/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.2199 - categorical_accuracy: 0.3070
# Epoch 268/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.1503 - categorical_accuracy: 0.1930
# Epoch 269/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 2.8818 - categorical_accuracy: 0.2281
# Epoch 270/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.1967 - categorical_accuracy: 0.2281
# Epoch 271/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 2.9301 - categorical_accuracy: 0.2456
# Epoch 272/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.8240 - categorical_accuracy: 0.2544
# Epoch 273/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 4.9813 - categorical_accuracy: 0.1491
# Epoch 274/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 8.1717 - categorical_accuracy: 0.2281
# Epoch 275/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 5.7747 - categorical_accuracy: 0.2368
# Epoch 276/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 7.0383 - categorical_accuracy: 0.2807
# Epoch 277/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 5.3634 - categorical_accuracy: 0.2368
# Epoch 278/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 5.0777 - categorical_accuracy: 0.3070
# Epoch 279/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 5.2439 - categorical_accuracy: 0.2807
# Epoch 280/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 5.1711 - categorical_accuracy: 0.2982
# Epoch 281/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 8.8786 - categorical_accuracy: 0.2281
# Epoch 282/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 4.9070 - categorical_accuracy: 0.2281
# Epoch 283/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 4.4929 - categorical_accuracy: 0.2807
# Epoch 284/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 3.9141 - categorical_accuracy: 0.2456
# Epoch 285/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 4.2972 - categorical_accuracy: 0.2456
# Epoch 286/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.6275 - categorical_accuracy: 0.3246
# Epoch 287/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 3.7151 - categorical_accuracy: 0.2719
# Epoch 288/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.7409 - categorical_accuracy: 0.2982
# Epoch 289/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.3220 - categorical_accuracy: 0.2719
# Epoch 290/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.1127 - categorical_accuracy: 0.3246
# Epoch 291/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 2.2029 - categorical_accuracy: 0.2807
# Epoch 292/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.3969 - categorical_accuracy: 0.2368
# Epoch 293/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.1079 - categorical_accuracy: 0.2632
# Epoch 294/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.0155 - categorical_accuracy: 0.2632
# Epoch 295/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.6543 - categorical_accuracy: 0.3596
# Epoch 296/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.3902 - categorical_accuracy: 0.2544
# Epoch 297/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.6560 - categorical_accuracy: 0.2895
# Epoch 298/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 2.6999 - categorical_accuracy: 0.2368
# Epoch 299/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 3.1273 - categorical_accuracy: 0.1930
# Epoch 300/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 3.0517 - categorical_accuracy: 0.2544
# Epoch 301/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 4.0247 - categorical_accuracy: 0.1930
# Epoch 302/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 3.1860 - categorical_accuracy: 0.2544
# Epoch 303/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 3.3098 - categorical_accuracy: 0.3070
# Epoch 304/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 3.0389 - categorical_accuracy: 0.2456
# Epoch 305/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.6225 - categorical_accuracy: 0.2895
# Epoch 306/2000
# 4/4 [==============================] - 0s 97ms/step - loss: 2.7807 - categorical_accuracy: 0.2807
# Epoch 307/2000
# 4/4 [==============================] - 0s 86ms/step - loss: 1.9286 - categorical_accuracy: 0.3333
# Epoch 308/2000
# 4/4 [==============================] - 0s 87ms/step - loss: 2.7655 - categorical_accuracy: 0.1667
# Epoch 309/2000
# 4/4 [==============================] - 0s 85ms/step - loss: 2.9333 - categorical_accuracy: 0.2544
# Epoch 310/2000
# 4/4 [==============================] - 0s 79ms/step - loss: 2.5161 - categorical_accuracy: 0.2368
# Epoch 311/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 1.8173 - categorical_accuracy: 0.2807
# Epoch 312/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 2.1748 - categorical_accuracy: 0.1842
# Epoch 313/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.9731 - categorical_accuracy: 0.2895
# Epoch 314/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 1.7231 - categorical_accuracy: 0.3509
# Epoch 315/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.0318 - categorical_accuracy: 0.2719
# Epoch 316/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 2.0798 - categorical_accuracy: 0.2281
# Epoch 317/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 2.2143 - categorical_accuracy: 0.2895
# Epoch 318/2000
# 4/4 [==============================] - 0s 78ms/step - loss: 2.2591 - categorical_accuracy: 0.2193
# Epoch 319/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.8866 - categorical_accuracy: 0.1842
# Epoch 320/2000
# 4/4 [==============================] - 0s 77ms/step - loss: 2.2829 - categorical_accuracy: 0.2895
# Epoch 321/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.3186 - categorical_accuracy: 0.2193
# Epoch 322/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.0989 - categorical_accuracy: 0.3860
# Epoch 323/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.4781 - categorical_accuracy: 0.2982
# Epoch 324/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.8931 - categorical_accuracy: 0.2632
# Epoch 325/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.7080 - categorical_accuracy: 0.2895
# Epoch 326/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 1.9108 - categorical_accuracy: 0.2895
# Epoch 327/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.8235 - categorical_accuracy: 0.2281
# Epoch 328/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 2.3882 - categorical_accuracy: 0.3509
# Epoch 329/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.9506 - categorical_accuracy: 0.2982
# Epoch 330/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.8587 - categorical_accuracy: 0.2982
# Epoch 331/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.1868 - categorical_accuracy: 0.2807
# Epoch 332/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.4747 - categorical_accuracy: 0.3070
# Epoch 333/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 2.6941 - categorical_accuracy: 0.2456
# Epoch 334/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 2.1141 - categorical_accuracy: 0.2368
# Epoch 335/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 1.9638 - categorical_accuracy: 0.2982
# Epoch 336/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.2372 - categorical_accuracy: 0.3158
# Epoch 337/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 2.4779 - categorical_accuracy: 0.3070
# Epoch 338/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.8556 - categorical_accuracy: 0.3509
# Epoch 339/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 1.9352 - categorical_accuracy: 0.3421
# Epoch 340/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.0543 - categorical_accuracy: 0.2895
# Epoch 341/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.5848 - categorical_accuracy: 0.2456
# Epoch 342/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.8987 - categorical_accuracy: 0.2281
# Epoch 343/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.8923 - categorical_accuracy: 0.2018
# Epoch 344/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 3.3995 - categorical_accuracy: 0.2281
# Epoch 345/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.1856 - categorical_accuracy: 0.3421
# Epoch 346/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 3.1441 - categorical_accuracy: 0.3246
# Epoch 347/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 3.5139 - categorical_accuracy: 0.2544
# Epoch 348/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.2648 - categorical_accuracy: 0.2544
# Epoch 349/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.2187 - categorical_accuracy: 0.2544
# Epoch 350/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.8242 - categorical_accuracy: 0.3070
# Epoch 351/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.7403 - categorical_accuracy: 0.2632
# Epoch 352/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.7397 - categorical_accuracy: 0.2895
# Epoch 353/2000
# 4/4 [==============================] - 0s 62ms/step - loss: 1.8119 - categorical_accuracy: 0.2982
# Epoch 354/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.4119 - categorical_accuracy: 0.3158
# Epoch 355/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.5430 - categorical_accuracy: 0.3246
# Epoch 356/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 2.8509 - categorical_accuracy: 0.2982
# Epoch 357/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 2.5973 - categorical_accuracy: 0.3070
# Epoch 358/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.6559 - categorical_accuracy: 0.2368
# Epoch 359/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.1848 - categorical_accuracy: 0.2368
# Epoch 360/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 3.1488 - categorical_accuracy: 0.2807
# Epoch 361/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 3.1360 - categorical_accuracy: 0.2544
# Epoch 362/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 4.6359 - categorical_accuracy: 0.2281
# Epoch 363/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 3.6221 - categorical_accuracy: 0.2982
# Epoch 364/2000
# 4/4 [==============================] - 0s 62ms/step - loss: 3.2032 - categorical_accuracy: 0.2632
# Epoch 365/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.8170 - categorical_accuracy: 0.2281
# Epoch 366/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 2.4526 - categorical_accuracy: 0.2982
# Epoch 367/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.7633 - categorical_accuracy: 0.3246
# Epoch 368/2000
# 4/4 [==============================] - 0s 61ms/step - loss: 1.6044 - categorical_accuracy: 0.2895
# Epoch 369/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 2.0571 - categorical_accuracy: 0.2807
# Epoch 370/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 1.7421 - categorical_accuracy: 0.3509
# Epoch 371/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 2.4786 - categorical_accuracy: 0.2719
# Epoch 372/2000
# 4/4 [==============================] - 0s 62ms/step - loss: 1.9531 - categorical_accuracy: 0.3421
# Epoch 373/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 1.8676 - categorical_accuracy: 0.2807
# Epoch 374/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.9110 - categorical_accuracy: 0.3684
# Epoch 375/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 2.4464 - categorical_accuracy: 0.3158
# Epoch 376/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 3.8882 - categorical_accuracy: 0.2544
# Epoch 377/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.7975 - categorical_accuracy: 0.3158
# Epoch 378/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 4.6294 - categorical_accuracy: 0.2368
# Epoch 379/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 5.6412 - categorical_accuracy: 0.1754
# Epoch 380/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 5.0523 - categorical_accuracy: 0.2368
# Epoch 381/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 5.2166 - categorical_accuracy: 0.2895
# Epoch 382/2000
# 4/4 [==============================] - 0s 62ms/step - loss: 4.4180 - categorical_accuracy: 0.3421
# Epoch 383/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 3.4922 - categorical_accuracy: 0.2018
# Epoch 384/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 3.5297 - categorical_accuracy: 0.3246
# Epoch 385/2000
# 4/4 [==============================] - 0s 64ms/step - loss: 3.2690 - categorical_accuracy: 0.2719
# Epoch 386/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 4.0803 - categorical_accuracy: 0.2544
# Epoch 387/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 3.0868 - categorical_accuracy: 0.3421
# Epoch 388/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 3.3698 - categorical_accuracy: 0.2982
# Epoch 389/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 3.5933 - categorical_accuracy: 0.2632
# Epoch 390/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 3.5487 - categorical_accuracy: 0.2719
# Epoch 391/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.8289 - categorical_accuracy: 0.2807
# Epoch 392/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 2.6727 - categorical_accuracy: 0.2895
# Epoch 393/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 2.7505 - categorical_accuracy: 0.3596
# Epoch 394/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 3.7737 - categorical_accuracy: 0.2807
# Epoch 395/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.7957 - categorical_accuracy: 0.2807
# Epoch 396/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.1159 - categorical_accuracy: 0.2982
# Epoch 397/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 2.2482 - categorical_accuracy: 0.2544
# Epoch 398/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.8759 - categorical_accuracy: 0.3246
# Epoch 399/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.2359 - categorical_accuracy: 0.2982
# Epoch 400/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 1.8399 - categorical_accuracy: 0.3596
# Epoch 401/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.2263 - categorical_accuracy: 0.3684
# Epoch 402/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 2.9725 - categorical_accuracy: 0.2193
# Epoch 403/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.2283 - categorical_accuracy: 0.2895
# Epoch 404/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.6965 - categorical_accuracy: 0.2807
# Epoch 405/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.6500 - categorical_accuracy: 0.2105
# Epoch 406/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 3.0767 - categorical_accuracy: 0.2018
# Epoch 407/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 2.2895 - categorical_accuracy: 0.2719
# Epoch 408/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.4417 - categorical_accuracy: 0.2719
# Epoch 409/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 2.2288 - categorical_accuracy: 0.3596
# Epoch 410/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 3.1268 - categorical_accuracy: 0.2368
# Epoch 411/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 2.6429 - categorical_accuracy: 0.3070
# Epoch 412/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.4631 - categorical_accuracy: 0.2368
# Epoch 413/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 3.3102 - categorical_accuracy: 0.3860
# Epoch 414/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.4196 - categorical_accuracy: 0.2544
# Epoch 415/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 2.6203 - categorical_accuracy: 0.2807
# Epoch 416/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 2.3620 - categorical_accuracy: 0.2544
# Epoch 417/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.3603 - categorical_accuracy: 0.2895
# Epoch 418/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 2.2294 - categorical_accuracy: 0.2719
# Epoch 419/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.6888 - categorical_accuracy: 0.3333
# Epoch 420/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 2.6355 - categorical_accuracy: 0.3158
# Epoch 421/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 2.9406 - categorical_accuracy: 0.2895
# Epoch 422/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 4.0712 - categorical_accuracy: 0.2719
# Epoch 423/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 3.0851 - categorical_accuracy: 0.3070
# Epoch 424/2000
# ...
# Epoch 1861/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.8989 - categorical_accuracy: 0.6667
# Epoch 1862/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.9136 - categorical_accuracy: 0.5263
# Epoch 1863/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.8028 - categorical_accuracy: 0.6579
# Epoch 1864/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.9561 - categorical_accuracy: 0.5877
# Epoch 1865/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.8917 - categorical_accuracy: 0.6667
# Epoch 1866/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8794 - categorical_accuracy: 0.6491
# Epoch 1867/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.9229 - categorical_accuracy: 0.5088
# Epoch 1868/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 1.1816 - categorical_accuracy: 0.5702
# Epoch 1869/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 1.0068 - categorical_accuracy: 0.5088
# Epoch 1870/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.1341 - categorical_accuracy: 0.5439
# Epoch 1871/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.0959 - categorical_accuracy: 0.4561
# Epoch 1872/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 1.0768 - categorical_accuracy: 0.5439
# Epoch 1873/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.0838 - categorical_accuracy: 0.6404
# Epoch 1874/2000
# 4/4 [==============================] - 0s 75ms/step - loss: 0.9895 - categorical_accuracy: 0.5526
# Epoch 1875/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.9412 - categorical_accuracy: 0.6316
# Epoch 1876/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.8080 - categorical_accuracy: 0.6316
# Epoch 1877/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.9865 - categorical_accuracy: 0.6140
# Epoch 1878/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.1729 - categorical_accuracy: 0.5263
# Epoch 1879/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 1.0496 - categorical_accuracy: 0.5526
# Epoch 1880/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.8531 - categorical_accuracy: 0.6316
# Epoch 1881/2000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.9289 - categorical_accuracy: 0.5965
# Epoch 1882/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.8879 - categorical_accuracy: 0.6053
# Epoch 1883/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 0.9060 - categorical_accuracy: 0.6228
# Epoch 1884/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.7913 - categorical_accuracy: 0.6754
# Epoch 1885/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8696 - categorical_accuracy: 0.6404
# Epoch 1886/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.7909 - categorical_accuracy: 0.7368
# Epoch 1887/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.0244 - categorical_accuracy: 0.5702
# Epoch 1888/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.9969 - categorical_accuracy: 0.5789
# Epoch 1889/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 1.5562 - categorical_accuracy: 0.3947
# Epoch 1890/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 1.5396 - categorical_accuracy: 0.4737
# Epoch 1891/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.2990 - categorical_accuracy: 0.5000
# Epoch 1892/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 1.0063 - categorical_accuracy: 0.5351
# Epoch 1893/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.7965 - categorical_accuracy: 0.7018
# Epoch 1894/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.7954 - categorical_accuracy: 0.6404
# Epoch 1895/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.9772 - categorical_accuracy: 0.6140
# Epoch 1896/2000
# 4/4 [==============================] - 0s 75ms/step - loss: 0.7293 - categorical_accuracy: 0.7193
# Epoch 1897/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.7783 - categorical_accuracy: 0.6404
# Epoch 1898/2000
# 4/4 [==============================] - 0s 80ms/step - loss: 0.8957 - categorical_accuracy: 0.5702
# Epoch 1899/2000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.7590 - categorical_accuracy: 0.6754
# Epoch 1900/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 1.0839 - categorical_accuracy: 0.5000
# Epoch 1901/2000
# 4/4 [==============================] - 0s 75ms/step - loss: 1.0905 - categorical_accuracy: 0.5175
# Epoch 1902/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.8478 - categorical_accuracy: 0.5877
# Epoch 1903/2000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.8648 - categorical_accuracy: 0.6228
# Epoch 1904/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 1.0987 - categorical_accuracy: 0.5175
# Epoch 1905/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 1.0039 - categorical_accuracy: 0.6316
# Epoch 1906/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 1.0363 - categorical_accuracy: 0.5526
# Epoch 1907/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.8465 - categorical_accuracy: 0.6228
# Epoch 1908/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.7287 - categorical_accuracy: 0.6754
# Epoch 1909/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8405 - categorical_accuracy: 0.6053
# Epoch 1910/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.8297 - categorical_accuracy: 0.6404
# Epoch 1911/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.9357 - categorical_accuracy: 0.6228
# Epoch 1912/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.8020 - categorical_accuracy: 0.6930
# Epoch 1913/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8121 - categorical_accuracy: 0.7281
# Epoch 1914/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.7919 - categorical_accuracy: 0.6404
# Epoch 1915/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 1.1010 - categorical_accuracy: 0.5263
# Epoch 1916/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.8301 - categorical_accuracy: 0.6316
# Epoch 1917/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.9890 - categorical_accuracy: 0.5439
# Epoch 1918/2000
# 4/4 [==============================] - 0s 75ms/step - loss: 1.2048 - categorical_accuracy: 0.5000
# Epoch 1919/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.1501 - categorical_accuracy: 0.5965
# Epoch 1920/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 1.0156 - categorical_accuracy: 0.5526
# Epoch 1921/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8553 - categorical_accuracy: 0.6228
# Epoch 1922/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.7778 - categorical_accuracy: 0.6316
# Epoch 1923/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8176 - categorical_accuracy: 0.7193
# Epoch 1924/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8844 - categorical_accuracy: 0.5702
# Epoch 1925/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8662 - categorical_accuracy: 0.5263
# Epoch 1926/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.7795 - categorical_accuracy: 0.6842
# Epoch 1927/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.8490 - categorical_accuracy: 0.6842
# Epoch 1928/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.7083 - categorical_accuracy: 0.7368
# Epoch 1929/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.9349 - categorical_accuracy: 0.5526
# Epoch 1930/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.2077 - categorical_accuracy: 0.5351
# Epoch 1931/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.1976 - categorical_accuracy: 0.4561
# Epoch 1932/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 1.0380 - categorical_accuracy: 0.5263
# Epoch 1933/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.0633 - categorical_accuracy: 0.5702
# Epoch 1934/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.8887 - categorical_accuracy: 0.5789
# Epoch 1935/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.9493 - categorical_accuracy: 0.5965
# Epoch 1936/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.9280 - categorical_accuracy: 0.5702
# Epoch 1937/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.9484 - categorical_accuracy: 0.6053
# Epoch 1938/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 1.2307 - categorical_accuracy: 0.4825
# Epoch 1939/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.4870 - categorical_accuracy: 0.4649
# Epoch 1940/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.0733 - categorical_accuracy: 0.5175
# Epoch 1941/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.1942 - categorical_accuracy: 0.5175
# Epoch 1942/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.1066 - categorical_accuracy: 0.5702
# Epoch 1943/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.2001 - categorical_accuracy: 0.4474
# Epoch 1944/2000
# 4/4 [==============================] - 0s 75ms/step - loss: 0.9618 - categorical_accuracy: 0.5877
# Epoch 1945/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.9579 - categorical_accuracy: 0.5614
# Epoch 1946/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.8564 - categorical_accuracy: 0.5789
# Epoch 1947/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.0440 - categorical_accuracy: 0.4825
# Epoch 1948/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.9626 - categorical_accuracy: 0.5351
# Epoch 1949/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8814 - categorical_accuracy: 0.5614
# Epoch 1950/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.8192 - categorical_accuracy: 0.6140
# Epoch 1951/2000
# 4/4 [==============================] - 0s 76ms/step - loss: 0.8585 - categorical_accuracy: 0.6140
# Epoch 1952/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.0314 - categorical_accuracy: 0.5614
# Epoch 1953/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.8577 - categorical_accuracy: 0.6140
# Epoch 1954/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.7807 - categorical_accuracy: 0.6579
# Epoch 1955/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.7744 - categorical_accuracy: 0.7193
# Epoch 1956/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.9007 - categorical_accuracy: 0.5789
# Epoch 1957/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.7569 - categorical_accuracy: 0.7193
# Epoch 1958/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.7203 - categorical_accuracy: 0.6316
# Epoch 1959/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.8008 - categorical_accuracy: 0.6842
# Epoch 1960/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.7240 - categorical_accuracy: 0.7193
# Epoch 1961/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.7009 - categorical_accuracy: 0.7193
# Epoch 1962/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.9628 - categorical_accuracy: 0.6053
# Epoch 1963/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.8229 - categorical_accuracy: 0.6228
# Epoch 1964/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.8761 - categorical_accuracy: 0.5439
# Epoch 1965/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.2322 - categorical_accuracy: 0.5351
# Epoch 1966/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.0032 - categorical_accuracy: 0.6053
# Epoch 1967/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.9363 - categorical_accuracy: 0.5789
# Epoch 1968/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 1.0231 - categorical_accuracy: 0.5000
# Epoch 1969/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.8871 - categorical_accuracy: 0.5614
# Epoch 1970/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.9734 - categorical_accuracy: 0.6228
# Epoch 1971/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 1.5014 - categorical_accuracy: 0.5965
# Epoch 1972/2000
# 4/4 [==============================] - 0s 73ms/step - loss: 1.0039 - categorical_accuracy: 0.5526
# Epoch 1973/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.9911 - categorical_accuracy: 0.6053
# Epoch 1974/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 1.0768 - categorical_accuracy: 0.5351
# Epoch 1975/2000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.0485 - categorical_accuracy: 0.4825
# Epoch 1976/2000
# 4/4 [==============================] - 0s 78ms/step - loss: 0.8136 - categorical_accuracy: 0.6579
# Epoch 1977/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.7218 - categorical_accuracy: 0.6842
# Epoch 1978/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.7630 - categorical_accuracy: 0.6404
# Epoch 1979/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6784 - categorical_accuracy: 0.7368
# Epoch 1980/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6815 - categorical_accuracy: 0.6667
# Epoch 1981/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.7158 - categorical_accuracy: 0.7193
# Epoch 1982/2000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.7320 - categorical_accuracy: 0.6754
# Epoch 1983/2000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.8617 - categorical_accuracy: 0.6404
# Epoch 1984/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.9184 - categorical_accuracy: 0.6228
# Epoch 1985/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.7597 - categorical_accuracy: 0.6316
# Epoch 1986/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.7652 - categorical_accuracy: 0.6930
# Epoch 1987/2000
# 4/4 [==============================] - 0s 80ms/step - loss: 0.7312 - categorical_accuracy: 0.6316
# Epoch 1988/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.6362 - categorical_accuracy: 0.7456
# Epoch 1989/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.7864 - categorical_accuracy: 0.7018
# Epoch 1990/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.7311 - categorical_accuracy: 0.6930
# Epoch 1991/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.8332 - categorical_accuracy: 0.6404
# Epoch 1992/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.8263 - categorical_accuracy: 0.6053
# Epoch 1993/2000
# 4/4 [==============================] - 0s 70ms/step - loss: 1.1407 - categorical_accuracy: 0.5789
# Epoch 1994/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.9208 - categorical_accuracy: 0.6404
# Epoch 1995/2000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.7918 - categorical_accuracy: 0.6228
# Epoch 1996/2000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.8313 - categorical_accuracy: 0.6053
# Epoch 1997/2000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.7981 - categorical_accuracy: 0.6842
# Epoch 1998/2000
# 4/4 [==============================] - 0s 72ms/step - loss: 1.1239 - categorical_accuracy: 0.5263
# Epoch 1999/2000
# 4/4 [==============================] - 0s 63ms/step - loss: 1.5144 - categorical_accuracy: 0.3772
# Epoch 2000/2000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.0461 - categorical_accuracy: 0.5351

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30, 64)            442112
#
#  lstm_4 (LSTM)               (None, 30, 128)           98816
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 596708 (2.28 MB)
# Trainable params: 596708 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

yhat = model.predict(X_test)

ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

accuracy_score(ytrue,yhat)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 0.5

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[5, 0],
#         [1, 0]],
#
#        [[2, 2],
#         [1, 1]],
#
#        [[5, 0],
#         [0, 1]],
#
#        [[3, 1],
#         [1, 1]]], dtype=int64)
